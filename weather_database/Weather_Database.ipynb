# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + city

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:    
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_description = city_weather["weather"][0]["description"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Current Description": city_description,
                            "Country": city_country,
                            "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | pascagoula
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | carmo do paranaiba
# Processing Record 8 of Set 1 | bilma
# Processing Record 9 of Set 1 | oistins
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | sikasso
# Processing Record 12 of Set 1 | caravelas
# Processing Record 13 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 1 | shache
# Processing Record 15 of Set 1 | trincomalee
# Processing Record 16 of Set 1 | araouane
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | saint george
# Processing Record 20 of Set 1 | asau
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | bathsheba
# Processing Record 26 of Set 1 | sioux lookout
# Processing Record 27 of Set 1 | kaeo
# Processing Record 28 of Set 1 | nagato
# Processing Record 29 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 1 | kaitangata
# Processing Record 31 of Set 1 | broome
# Processing Record 32 of Set 1 | ilulissat
# Processing Record 33 of Set 1 | staropesterevo
# Processing Record 34 of Set 1 | nabire
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | ust-uda
# Processing Record 38 of Set 1 | ulladulla
# Processing Record 39 of Set 1 | neyyattinkara
# Processing Record 40 of Set 1 | mende
# Processing Record 41 of Set 1 | berdigestyakh
# Processing Record 42 of Set 1 | lavrentiya
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | kolo
# Processing Record 45 of Set 1 | flinders
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | camocim
# Processing Record 48 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | firminy
# Processing Record 1 of Set 2 | saldanha
# Processing Record 2 of Set 2 | geraldton
# Processing Record 3 of Set 2 | maumere
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | lorengau
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | makaha
# Processing Record 8 of Set 2 | sao felix do xingu
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | tuy hoa
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | nkhotakota
# Processing Record 13 of Set 2 | boddam
# Processing Record 14 of Set 2 | thap than
# Processing Record 15 of Set 2 | waldkraiburg
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | algeciras
# Processing Record 18 of Set 2 | filadelfia
# Processing Record 19 of Set 2 | riohacha
# Processing Record 20 of Set 2 | senanga
# Processing Record 21 of Set 2 | fort nelson
# Processing Record 22 of Set 2 | aloleng
# Processing Record 23 of Set 2 | kainantu
# Processing Record 24 of Set 2 | khatanga
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | iqaluit
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | sitka
# Processing Record 31 of Set 2 | kamenka
# Processing Record 32 of Set 2 | abadan
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 35 of Set 2 | san rafael
# Processing Record 36 of Set 2 | tazovskiy
# Processing Record 37 of Set 2 | russell
# Processing Record 38 of Set 2 | porbandar
# Processing Record 39 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 2 | chokurdakh
# Processing Record 41 of Set 2 | upernavik
# Processing Record 42 of Set 2 | ellisras
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | roanoke
# Processing Record 45 of Set 2 | tarbagatay
# Processing Record 46 of Set 2 | arraial do cabo
# Processing Record 47 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 48 of Set 2 | okhotsk
# Processing Record 49 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 2 | poznan
# Processing Record 1 of Set 3 | aykhal
# Processing Record 2 of Set 3 | laguna
# Processing Record 3 of Set 3 | baghdad
# Processing Record 4 of Set 3 | jinji
# Processing Record 5 of Set 3 | gondar
# Processing Record 6 of Set 3 | butaritari
# Processing Record 7 of Set 3 | esna
# Processing Record 8 of Set 3 | mergui
# City not found. Skipping...
# Processing Record 9 of Set 3 | san juan
# Processing Record 10 of Set 3 | masallatah
# Processing Record 11 of Set 3 | mareeba
# Processing Record 12 of Set 3 | shihezi
# Processing Record 13 of Set 3 | orlik
# Processing Record 14 of Set 3 | menongue
# Processing Record 15 of Set 3 | merauke
# Processing Record 16 of Set 3 | pisco
# Processing Record 17 of Set 3 | maragogi
# Processing Record 18 of Set 3 | riaba
# City not found. Skipping...
# Processing Record 19 of Set 3 | ancud
# Processing Record 20 of Set 3 | charters towers
# Processing Record 21 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 3 | winchester
# Processing Record 23 of Set 3 | cape town
# Processing Record 24 of Set 3 | tallahassee
# Processing Record 25 of Set 3 | hilo
# Processing Record 26 of Set 3 | ambilobe
# Processing Record 27 of Set 3 | bredasdorp
# Processing Record 28 of Set 3 | port elizabeth
# Processing Record 29 of Set 3 | makubetsu
# Processing Record 30 of Set 3 | north bend
# Processing Record 31 of Set 3 | souillac
# Processing Record 32 of Set 3 | cheyenne
# Processing Record 33 of Set 3 | kayiry
# Processing Record 34 of Set 3 | leningradskiy
# Processing Record 35 of Set 3 | nome
# Processing Record 36 of Set 3 | castro
# Processing Record 37 of Set 3 | manjacaze
# Processing Record 38 of Set 3 | vysokogornyy
# Processing Record 39 of Set 3 | dingle
# Processing Record 40 of Set 3 | cidreira
# Processing Record 41 of Set 3 | tete
# Processing Record 42 of Set 3 | chuy
# Processing Record 43 of Set 3 | miri
# Processing Record 44 of Set 3 | muravlenko
# Processing Record 45 of Set 3 | tuatapere
# Processing Record 46 of Set 3 | port lincoln
# Processing Record 47 of Set 3 | georgetown
# Processing Record 48 of Set 3 | vsevolodo-vilva
# City not found. Skipping...
# Processing Record 49 of Set 3 | airai
# Processing Record 50 of Set 3 | ola
# Processing Record 1 of Set 4 | mikumi
# Processing Record 2 of Set 4 | coquimbo
# Processing Record 3 of Set 4 | tripoli
# Processing Record 4 of Set 4 | kirakira
# Processing Record 5 of Set 4 | sao paulo de olivenca
# Processing Record 6 of Set 4 | henties bay
# Processing Record 7 of Set 4 | san patricio
# Processing Record 8 of Set 4 | isangel
# Processing Record 9 of Set 4 | bengkulu
# Processing Record 10 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 11 of Set 4 | cherskiy
# Processing Record 12 of Set 4 | lebu
# Processing Record 13 of Set 4 | nikolskoye
# Processing Record 14 of Set 4 | yuncheng
# Processing Record 15 of Set 4 | acapulco
# Processing Record 16 of Set 4 | lima
# Processing Record 17 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 18 of Set 4 | ketchikan
# Processing Record 19 of Set 4 | nizwa
# Processing Record 20 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 4 | shubarkuduk
# Processing Record 22 of Set 4 | lata
# Processing Record 23 of Set 4 | piacabucu
# Processing Record 24 of Set 4 | danilovka
# Processing Record 25 of Set 4 | nanortalik
# Processing Record 26 of Set 4 | andra
# Processing Record 27 of Set 4 | amapa
# Processing Record 28 of Set 4 | naron
# Processing Record 29 of Set 4 | torbay
# Processing Record 30 of Set 4 | ndele
# Processing Record 31 of Set 4 | krasnoselkup
# Processing Record 32 of Set 4 | panzhihua
# Processing Record 33 of Set 4 | constitucion
# Processing Record 34 of Set 4 | urucui
# Processing Record 35 of Set 4 | coahuayana
# Processing Record 36 of Set 4 | kasongo-lunda
# Processing Record 37 of Set 4 | kalengwa
# Processing Record 38 of Set 4 | koungou
# Processing Record 39 of Set 4 | roma
# Processing Record 40 of Set 4 | garissa
# Processing Record 41 of Set 4 | clyde river
# Processing Record 42 of Set 4 | victoria
# Processing Record 43 of Set 4 | richards bay
# Processing Record 44 of Set 4 | coihaique
# Processing Record 45 of Set 4 | talcahuano
# Processing Record 46 of Set 4 | bambous virieux
# Processing Record 47 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 4 | aklavik
# Processing Record 49 of Set 4 | vardo
# Processing Record 50 of Set 4 | yerbogachen
# Processing Record 1 of Set 5 | saskylakh
# Processing Record 2 of Set 5 | ribeira grande
# Processing Record 3 of Set 5 | lagoa
# Processing Record 4 of Set 5 | teeli
# Processing Record 5 of Set 5 | mindelo
# Processing Record 6 of Set 5 | el alto
# Processing Record 7 of Set 5 | rawson
# Processing Record 8 of Set 5 | wainwright
# Processing Record 9 of Set 5 | poum
# Processing Record 10 of Set 5 | corsicana
# Processing Record 11 of Set 5 | dikson
# Processing Record 12 of Set 5 | pradera
# Processing Record 13 of Set 5 | marihatag
# Processing Record 14 of Set 5 | ust-kuyga
# Processing Record 15 of Set 5 | ouadda
# Processing Record 16 of Set 5 | walvis bay
# Processing Record 17 of Set 5 | montego bay
# Processing Record 18 of Set 5 | rio grande
# Processing Record 19 of Set 5 | chipinge
# Processing Record 20 of Set 5 | cayenne
# Processing Record 21 of Set 5 | hualmay
# Processing Record 22 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 5 | noumea
# Processing Record 24 of Set 5 | east london
# Processing Record 25 of Set 5 | wakkanai
# Processing Record 26 of Set 5 | awjilah
# Processing Record 27 of Set 5 | togur
# Processing Record 28 of Set 5 | havoysund
# Processing Record 29 of Set 5 | road town
# Processing Record 30 of Set 5 | norman wells
# Processing Record 31 of Set 5 | san cristobal
# Processing Record 32 of Set 5 | andenes
# Processing Record 33 of Set 5 | yellowknife
# Processing Record 34 of Set 5 | samarai
# Processing Record 35 of Set 5 | iquique
# Processing Record 36 of Set 5 | hofn
# Processing Record 37 of Set 5 | turtkul
# City not found. Skipping...
# Processing Record 38 of Set 5 | namatanai
# Processing Record 39 of Set 5 | grao mogol
# Processing Record 40 of Set 5 | ohara
# Processing Record 41 of Set 5 | kamphaeng phet
# Processing Record 42 of Set 5 | taoudenni
# Processing Record 43 of Set 5 | nadym
# Processing Record 44 of Set 5 | hithadhoo
# Processing Record 45 of Set 5 | cairns
# Processing Record 46 of Set 5 | porto novo
# Processing Record 47 of Set 5 | manokwari
# Processing Record 48 of Set 5 | qaqortoq
# Processing Record 49 of Set 5 | fortuna
# Processing Record 50 of Set 5 | vila franca do campo
# Processing Record 1 of Set 6 | port hedland
# Processing Record 2 of Set 6 | mandan
# Processing Record 3 of Set 6 | kuloy
# Processing Record 4 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 6 | itarema
# Processing Record 6 of Set 6 | igarka
# Processing Record 7 of Set 6 | la ronge
# Processing Record 8 of Set 6 | port macquarie
# Processing Record 9 of Set 6 | kavaratti
# Processing Record 10 of Set 6 | narsaq
# Processing Record 11 of Set 6 | sungaipenuh
# Processing Record 12 of Set 6 | monrovia
# Processing Record 13 of Set 6 | pemangkat
# Processing Record 14 of Set 6 | luderitz
# Processing Record 15 of Set 6 | severo-kurilsk
# Processing Record 16 of Set 6 | rzeszow
# Processing Record 17 of Set 6 | sakakah
# Processing Record 18 of Set 6 | tiksi
# Processing Record 19 of Set 6 | zolotinka
# City not found. Skipping...
# Processing Record 20 of Set 6 | dafeng
# Processing Record 21 of Set 6 | kurilsk
# Processing Record 22 of Set 6 | faya
# Processing Record 23 of Set 6 | guadalupe victoria
# Processing Record 24 of Set 6 | alofi
# Processing Record 25 of Set 6 | hearst
# Processing Record 26 of Set 6 | acari
# Processing Record 27 of Set 6 | kavieng
# Processing Record 28 of Set 6 | lucea
# Processing Record 29 of Set 6 | ostrovnoy
# Processing Record 30 of Set 6 | sabang
# Processing Record 31 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 6 | dunedin
# Processing Record 33 of Set 6 | ambovombe
# Processing Record 34 of Set 6 | nevelsk
# Processing Record 35 of Set 6 | cabo san lucas
# Processing Record 36 of Set 6 | dzilam gonzalez
# Processing Record 37 of Set 6 | sabla
# Processing Record 38 of Set 6 | guerrero negro
# Processing Record 39 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 6 | goderich
# Processing Record 41 of Set 6 | tasiilaq
# Processing Record 42 of Set 6 | puerto narino
# Processing Record 43 of Set 6 | nhulunbuy
# Processing Record 44 of Set 6 | dillon
# Processing Record 45 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 6 | verkhnevilyuysk
# Processing Record 47 of Set 6 | kui buri
# Processing Record 48 of Set 6 | rosarito
# Processing Record 49 of Set 6 | spornoye
# Processing Record 50 of Set 6 | visby
# Processing Record 1 of Set 7 | ballina
# Processing Record 2 of Set 7 | westport
# Processing Record 3 of Set 7 | olinda
# Processing Record 4 of Set 7 | balabac
# Processing Record 5 of Set 7 | hervey bay
# Processing Record 6 of Set 7 | morant bay
# Processing Record 7 of Set 7 | bethel
# Processing Record 8 of Set 7 | yarmouth
# Processing Record 9 of Set 7 | aripuana
# Processing Record 10 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 11 of Set 7 | guangyuan
# Processing Record 12 of Set 7 | sur
# Processing Record 13 of Set 7 | vesoul
# Processing Record 14 of Set 7 | nemuro
# Processing Record 15 of Set 7 | malayal
# Processing Record 16 of Set 7 | wajir
# Processing Record 17 of Set 7 | klaksvik
# Processing Record 18 of Set 7 | margate
# Processing Record 19 of Set 7 | touros
# Processing Record 20 of Set 7 | sholapur
# Processing Record 21 of Set 7 | calabozo
# Processing Record 22 of Set 7 | saint-augustin
# Processing Record 23 of Set 7 | los llanos de aridane
# Processing Record 24 of Set 7 | newton
# Processing Record 25 of Set 7 | nushki
# Processing Record 26 of Set 7 | comodoro rivadavia
# Processing Record 27 of Set 7 | ust-maya
# Processing Record 28 of Set 7 | bilibino
# Processing Record 29 of Set 7 | nagaur
# Processing Record 30 of Set 7 | dwarka
# Processing Record 31 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 32 of Set 7 | hamilton
# Processing Record 33 of Set 7 | adre
# Processing Record 34 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 7 | huicheng
# Processing Record 36 of Set 7 | casino
# Processing Record 37 of Set 7 | faanui
# Processing Record 38 of Set 7 | tynda
# Processing Record 39 of Set 7 | saint-ambroise
# Processing Record 40 of Set 7 | te anau
# Processing Record 41 of Set 7 | genhe
# Processing Record 42 of Set 7 | tomigusuku
# Processing Record 43 of Set 7 | praia da vitoria
# Processing Record 44 of Set 7 | vila
# Processing Record 45 of Set 7 | redwater
# Processing Record 46 of Set 7 | port-gentil
# Processing Record 47 of Set 7 | korla
# Processing Record 48 of Set 7 | akyab
# Processing Record 49 of Set 7 | portland
# Processing Record 50 of Set 7 | mount gambier
# Processing Record 1 of Set 8 | provideniya
# Processing Record 2 of Set 8 | san quintin
# Processing Record 3 of Set 8 | emerald
# Processing Record 4 of Set 8 | kamalpur
# Processing Record 5 of Set 8 | koson
# Processing Record 6 of Set 8 | songea
# Processing Record 7 of Set 8 | baragua
# Processing Record 8 of Set 8 | pangkalanbuun
# Processing Record 9 of Set 8 | jalu
# Processing Record 10 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 11 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 12 of Set 8 | shepsi
# Processing Record 13 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 8 | sierra vista
# Processing Record 15 of Set 8 | cap malheureux
# Processing Record 16 of Set 8 | hundested
# Processing Record 17 of Set 8 | komsomolskiy
# Processing Record 18 of Set 8 | mayo
# Processing Record 19 of Set 8 | bambanglipuro
# Processing Record 20 of Set 8 | sangar
# Processing Record 21 of Set 8 | skibbereen
# Processing Record 22 of Set 8 | hvittingfoss
# Processing Record 23 of Set 8 | kahului
# Processing Record 24 of Set 8 | glendive
# Processing Record 25 of Set 8 | karasjok
# Processing Record 26 of Set 8 | bintulu
# Processing Record 27 of Set 8 | dickinson
# Processing Record 28 of Set 8 | turukhansk
# Processing Record 29 of Set 8 | salalah
# Processing Record 30 of Set 8 | kayes
# Processing Record 31 of Set 8 | lander
# Processing Record 32 of Set 8 | chachapoyas
# Processing Record 33 of Set 8 | kruisfontein
# Processing Record 34 of Set 8 | shingu
# Processing Record 35 of Set 8 | rafaela
# Processing Record 36 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 8 | nizhniy kuranakh
# Processing Record 38 of Set 8 | otradnoye
# Processing Record 39 of Set 8 | pacific grove
# Processing Record 40 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 41 of Set 8 | durant
# Processing Record 42 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 8 | nijkerk
# Processing Record 44 of Set 8 | abu jubayhah
# City not found. Skipping...
# Processing Record 45 of Set 8 | longyearbyen
# Processing Record 46 of Set 8 | berlevag
# Processing Record 47 of Set 8 | yeletskiy
# City not found. Skipping...
# Processing Record 48 of Set 8 | altamira
# Processing Record 49 of Set 8 | swan river
# Processing Record 50 of Set 8 | zemio
# Processing Record 1 of Set 9 | sao filipe
# Processing Record 2 of Set 9 | kalmunai
# Processing Record 3 of Set 9 | kedrovyy
# Processing Record 4 of Set 9 | porto belo
# Processing Record 5 of Set 9 | zyryanka
# Processing Record 6 of Set 9 | kempele
# Processing Record 7 of Set 9 | katsuura
# Processing Record 8 of Set 9 | kontagora
# Processing Record 9 of Set 9 | andilamena
# Processing Record 10 of Set 9 | chabahar
# Processing Record 11 of Set 9 | chowchilla
# Processing Record 12 of Set 9 | ust-karsk
# Processing Record 13 of Set 9 | pasighat
# Processing Record 14 of Set 9 | port hardy
# Processing Record 15 of Set 9 | kamaishi
# Processing Record 16 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 9 | antofagasta
# Processing Record 18 of Set 9 | vostok
# Processing Record 19 of Set 9 | ambulu
# Processing Record 20 of Set 9 | ossora
# Processing Record 21 of Set 9 | gizo
# Processing Record 22 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 23 of Set 9 | barcelos
# Processing Record 24 of Set 9 | chateaubelair
# Processing Record 25 of Set 9 | avera
# Processing Record 26 of Set 9 | port-cartier
# Processing Record 27 of Set 9 | burica
# City not found. Skipping...
# Processing Record 28 of Set 9 | ye
# City not found. Skipping...
# Processing Record 29 of Set 9 | upington
# Processing Record 30 of Set 9 | ischia
# Processing Record 31 of Set 9 | nogliki
# Processing Record 32 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 9 | lagunas
# Processing Record 34 of Set 9 | kandrian
# Processing Record 35 of Set 9 | haines junction
# Processing Record 36 of Set 9 | balkhash
# Processing Record 37 of Set 9 | kununurra
# Processing Record 38 of Set 9 | novosibirsk
# Processing Record 39 of Set 9 | paraiso
# Processing Record 40 of Set 9 | skelleftea
# Processing Record 41 of Set 9 | roald
# Processing Record 42 of Set 9 | sadiqabad
# Processing Record 43 of Set 9 | dyurtyuli
# Processing Record 44 of Set 9 | wanning
# Processing Record 45 of Set 9 | ambajogai
# Processing Record 46 of Set 9 | lensk
# Processing Record 47 of Set 9 | mar del plata
# Processing Record 48 of Set 9 | baracoa
# Processing Record 49 of Set 9 | beloha
# Processing Record 50 of Set 9 | hanmer springs
# Processing Record 1 of Set 10 | hambantota
# Processing Record 2 of Set 10 | biak
# Processing Record 3 of Set 10 | kendari
# Processing Record 4 of Set 10 | husavik
# Processing Record 5 of Set 10 | vestmannaeyjar
# Processing Record 6 of Set 10 | tigil
# Processing Record 7 of Set 10 | maningrida
# Processing Record 8 of Set 10 | kathu
# Processing Record 9 of Set 10 | tambura
# Processing Record 10 of Set 10 | tomatlan
# Processing Record 11 of Set 10 | daru
# Processing Record 12 of Set 10 | ornskoldsvik
# Processing Record 13 of Set 10 | petrov val
# Processing Record 14 of Set 10 | mount isa
# Processing Record 15 of Set 10 | ushtobe
# Processing Record 16 of Set 10 | pevek
# Processing Record 17 of Set 10 | goose creek
# Processing Record 18 of Set 10 | gimli
# Processing Record 19 of Set 10 | trairi
# Processing Record 20 of Set 10 | olafsvik
# Processing Record 21 of Set 10 | zhuhai
# Processing Record 22 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 10 | lompoc
# Processing Record 24 of Set 10 | mogadishu
# Processing Record 25 of Set 10 | buckeye
# Processing Record 26 of Set 10 | west plains
# Processing Record 27 of Set 10 | tautira
# Processing Record 28 of Set 10 | baruun-urt
# Processing Record 29 of Set 10 | la roche-sur-yon
# Processing Record 30 of Set 10 | brae
# Processing Record 31 of Set 10 | leuwiliang
# Processing Record 32 of Set 10 | kouango
# Processing Record 33 of Set 10 | naustdal
# Processing Record 34 of Set 10 | pierre
# Processing Record 35 of Set 10 | talnakh
# Processing Record 36 of Set 10 | prince rupert
# Processing Record 37 of Set 10 | grand gaube
# Processing Record 38 of Set 10 | ovalle
# Processing Record 39 of Set 10 | saint anthony
# Processing Record 40 of Set 10 | katghora
# Processing Record 41 of Set 10 | itamaraca
# Processing Record 42 of Set 10 | rivera
# Processing Record 43 of Set 10 | tinqueux
# Processing Record 44 of Set 10 | petatlan
# Processing Record 45 of Set 10 | kudahuvadhoo
# Processing Record 46 of Set 10 | seoul
# Processing Record 47 of Set 10 | nouakchott
# Processing Record 48 of Set 10 | vitimskiy
# City not found. Skipping...
# Processing Record 49 of Set 10 | hastings
# Processing Record 50 of Set 10 | atar
# Processing Record 1 of Set 11 | hami
# Processing Record 2 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 11 | ekuvukeni
# Processing Record 4 of Set 11 | sibu
# Processing Record 5 of Set 11 | wagar
# Processing Record 6 of Set 11 | cam ranh
# Processing Record 7 of Set 11 | thinadhoo
# Processing Record 8 of Set 11 | agadez
# Processing Record 9 of Set 11 | college
# Processing Record 10 of Set 11 | harper
# Processing Record 11 of Set 11 | rocha
# Processing Record 12 of Set 11 | masunga
# Processing Record 13 of Set 11 | bereda
# Processing Record 14 of Set 11 | sorong
# Processing Record 15 of Set 11 | kizema
# Processing Record 16 of Set 11 | yenagoa
# Processing Record 17 of Set 11 | kalur kot
# Processing Record 18 of Set 11 | nouadhibou
# Processing Record 19 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 11 | whithorn
# Processing Record 21 of Set 11 | paita
# Processing Record 22 of Set 11 | buala
# Processing Record 23 of Set 11 | san miguel
# Processing Record 24 of Set 11 | fez
# Processing Record 25 of Set 11 | taguatinga
# Processing Record 26 of Set 11 | kerrville
# Processing Record 27 of Set 11 | mehamn
# Processing Record 28 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 29 of Set 11 | viedma
# Processing Record 30 of Set 11 | kungurtug
# Processing Record 31 of Set 11 | chumikan
# Processing Record 32 of Set 11 | bosaso
# Processing Record 33 of Set 11 | mahina
# Processing Record 34 of Set 11 | thetford mines
# Processing Record 35 of Set 11 | jurm
# Processing Record 36 of Set 11 | borogontsy
# Processing Record 37 of Set 11 | atasu
# Processing Record 38 of Set 11 | padang
# Processing Record 39 of Set 11 | ngunguru
# Processing Record 40 of Set 11 | marsa matruh
# Processing Record 41 of Set 11 | fuerte olimpo
# Processing Record 42 of Set 11 | morro bay
# Processing Record 43 of Set 11 | peno
# Processing Record 44 of Set 11 | maarianhamina
# Processing Record 45 of Set 11 | shiyan
# Processing Record 46 of Set 11 | grand forks
# Processing Record 47 of Set 11 | raudeberg
# Processing Record 48 of Set 11 | leh
# Processing Record 49 of Set 11 | bu salim
# City not found. Skipping...
# Processing Record 50 of Set 11 | rudnichnyy
# Processing Record 1 of Set 12 | kongolo
# Processing Record 2 of Set 12 | the pas
# Processing Record 3 of Set 12 | muroto
# Processing Record 4 of Set 12 | caluquembe
# Processing Record 5 of Set 12 | blagoyevo
# Processing Record 6 of Set 12 | balsas
# Processing Record 7 of Set 12 | lewiston
# Processing Record 8 of Set 12 | ahipara
# Processing Record 9 of Set 12 | cheney
# Processing Record 10 of Set 12 | moron
# Processing Record 11 of Set 12 | onega
# Processing Record 12 of Set 12 | tucuman
# Processing Record 13 of Set 12 | aseri
# Processing Record 14 of Set 12 | baykit
# Processing Record 15 of Set 12 | artyshta
# Processing Record 16 of Set 12 | nan
# Processing Record 17 of Set 12 | osa
# Processing Record 18 of Set 12 | whitianga
# Processing Record 19 of Set 12 | axim
# Processing Record 20 of Set 12 | shuya
# Processing Record 21 of Set 12 | tornio
# Processing Record 22 of Set 12 | cauquenes
# Processing Record 23 of Set 12 | grindavik
# Processing Record 24 of Set 12 | trinidad
# Processing Record 25 of Set 12 | astana
# Processing Record 26 of Set 12 | alyangula
# Processing Record 27 of Set 12 | marquette
# Processing Record 28 of Set 12 | arkhangelsk
# Processing Record 29 of Set 12 | kalangala
# Processing Record 30 of Set 12 | abuyog
# Processing Record 31 of Set 12 | whitecourt
# Processing Record 32 of Set 12 | kamina
# Processing Record 33 of Set 12 | sola
# Processing Record 34 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 35 of Set 12 | palamos
# Processing Record 36 of Set 12 | jieshi
# Processing Record 37 of Set 12 | thohoyandou
# Processing Record 38 of Set 12 | codrington
# Processing Record 39 of Set 12 | bull savanna
# Processing Record 40 of Set 12 | nelson bay
# Processing Record 41 of Set 12 | camana
# Processing Record 42 of Set 12 | sao jose da coroa grande
# Processing Record 43 of Set 12 | kalinovo
# Processing Record 44 of Set 12 | dhuwaran
# Processing Record 45 of Set 12 | pinsk
# Processing Record 46 of Set 12 | bandarbeyla
# Processing Record 47 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 12 | zhigansk
# Processing Record 49 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 50 of Set 12 | lira
# Processing Record 1 of Set 13 | buraydah
# Processing Record 2 of Set 13 | booue
# Processing Record 3 of Set 13 | lincoln
# Processing Record 4 of Set 13 | smithers
# Processing Record 5 of Set 13 | kinablangan
# Processing Record 6 of Set 13 | westerland
# Processing Record 7 of Set 13 | fairbanks
# Processing Record 8 of Set 13 | petrokamenskoye
# Processing Record 9 of Set 13 | nyurba
# Processing Record 10 of Set 13 | rockport
# Processing Record 11 of Set 13 | mayumba
# Processing Record 12 of Set 13 | upata
# Processing Record 13 of Set 13 | lazaro cardenas
# Processing Record 14 of Set 13 | quatre cocos
# Processing Record 15 of Set 13 | kimbe
# Processing Record 16 of Set 13 | mikhaylovskoye
# Processing Record 17 of Set 13 | ozernovskiy
# Processing Record 18 of Set 13 | inverell
# Processing Record 19 of Set 13 | verkhniye tatyshly
# Processing Record 20 of Set 13 | maroantsetra
# Processing Record 21 of Set 13 | yar-sale
# Processing Record 22 of Set 13 | doba
# Processing Record 23 of Set 13 | inta
# Processing Record 24 of Set 13 | lasa
# Processing Record 25 of Set 13 | deputatskiy
# Processing Record 26 of Set 13 | labuhan
# Processing Record 27 of Set 13 | sosnovo-ozerskoye
# Processing Record 28 of Set 13 | tilichiki
# Processing Record 29 of Set 13 | rincon
# Processing Record 30 of Set 13 | asosa
# Processing Record 31 of Set 13 | leua
# Processing Record 32 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 33 of Set 13 | angoche
# Processing Record 34 of Set 13 | udachnyy
# Processing Record 35 of Set 13 | escarcega
# Processing Record 36 of Set 13 | challapata
# Processing Record 37 of Set 13 | porosozero
# Processing Record 38 of Set 13 | camalu
# Processing Record 39 of Set 13 | savannah bight
# Processing Record 40 of Set 13 | kathmandu
# Processing Record 41 of Set 13 | pringsewu
# Processing Record 42 of Set 13 | hasaki
# Processing Record 43 of Set 13 | chatrapur
# Processing Record 44 of Set 13 | keningau
# Processing Record 45 of Set 13 | gbadolite
# Processing Record 46 of Set 13 | galesong
# Processing Record 47 of Set 13 | katangi
# Processing Record 48 of Set 13 | rudbar
# Processing Record 49 of Set 13 | bud
# Processing Record 50 of Set 13 | dudinka
# Processing Record 1 of Set 14 | okha
# Processing Record 2 of Set 14 | harsud
# Processing Record 3 of Set 14 | soe
# Processing Record 4 of Set 14 | vanavara
# Processing Record 5 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 6 of Set 14 | pangnirtung
# Processing Record 7 of Set 14 | eucaliptus
# Processing Record 8 of Set 14 | tabou
# Processing Record 9 of Set 14 | qingyuan
# Processing Record 10 of Set 14 | gibara
# Processing Record 11 of Set 14 | zinder
# Processing Record 12 of Set 14 | fasa
# Processing Record 13 of Set 14 | omboue
# Processing Record 14 of Set 14 | alice springs
# Processing Record 15 of Set 14 | bolivar
# Processing Record 16 of Set 14 | sochi
# Processing Record 17 of Set 14 | desterro
# Processing Record 18 of Set 14 | neuquen
# Processing Record 19 of Set 14 | barra do garcas
# Processing Record 20 of Set 14 | dhidhdhoo
# Processing Record 21 of Set 14 | peterhead
# Processing Record 22 of Set 14 | vilhena
# Processing Record 23 of Set 14 | zhuanghe
# Processing Record 24 of Set 14 | nanakuli
# Processing Record 25 of Set 14 | silyanah
# City not found. Skipping...
# Processing Record 26 of Set 14 | manicore
# Processing Record 27 of Set 14 | naze
# Processing Record 28 of Set 14 | oyama
# Processing Record 29 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 30 of Set 14 | uitenhage
# Processing Record 31 of Set 14 | myaundzha
# Processing Record 32 of Set 14 | kovvur
# Processing Record 33 of Set 14 | solnechnyy
# Processing Record 34 of Set 14 | methoni
# Processing Record 35 of Set 14 | alta floresta
# Processing Record 36 of Set 14 | san carlos de bariloche
# Processing Record 37 of Set 14 | jiuquan
# Processing Record 38 of Set 14 | macklin
# Processing Record 39 of Set 14 | catuday
# Processing Record 40 of Set 14 | beira
# Processing Record 41 of Set 14 | jequitinhonha
# Processing Record 42 of Set 14 | gonzales
# Processing Record 43 of Set 14 | mpika
# Processing Record 44 of Set 14 | mosquera
# Processing Record 45 of Set 14 | poso
# Processing Record 46 of Set 14 | fulton
# Processing Record 47 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 48 of Set 14 | sulurpeta
# City not found. Skipping...
# Processing Record 49 of Set 14 | makhu
# Processing Record 50 of Set 14 | santa rosa
# Processing Record 1 of Set 15 | annau
# Processing Record 2 of Set 15 | chimbote
# Processing Record 3 of Set 15 | nuuk
# Processing Record 4 of Set 15 | fomboni
# Processing Record 5 of Set 15 | ducheng
# Processing Record 6 of Set 15 | la asuncion
# Processing Record 7 of Set 15 | ayiasos
# City not found. Skipping...
# Processing Record 8 of Set 15 | asyut
# Processing Record 9 of Set 15 | kidal
# Processing Record 10 of Set 15 | gornopravdinsk
# Processing Record 11 of Set 15 | grants pass
# Processing Record 12 of Set 15 | keti bandar
# Processing Record 13 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 15 | brufut
# Processing Record 15 of Set 15 | tura
# Processing Record 16 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 15 | shevchenkove
# Processing Record 18 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 15 | erzin
# Processing Record 20 of Set 15 | la macarena
# Processing Record 21 of Set 15 | saint-georges
# Processing Record 22 of Set 15 | kieta
# Processing Record 23 of Set 15 | farah
# Processing Record 24 of Set 15 | hrinova
# Processing Record 25 of Set 15 | lindsay
# Processing Record 26 of Set 15 | todos santos
# Processing Record 27 of Set 15 | rabo de peixe
# Processing Record 28 of Set 15 | bezopasnoye
# Processing Record 29 of Set 15 | trebukhiv
# Processing Record 30 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 15 | eyrarbakki
# Processing Record 32 of Set 15 | vila velha
# Processing Record 33 of Set 15 | tikhvin
# Processing Record 34 of Set 15 | sergeyevka
# Processing Record 35 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 36 of Set 15 | pianoro
# Processing Record 37 of Set 15 | necochea
# Processing Record 38 of Set 15 | ixtapa
# Processing Record 39 of Set 15 | nioro
# Processing Record 40 of Set 15 | gavle
# Processing Record 41 of Set 15 | ninghai
# Processing Record 42 of Set 15 | aguimes
# Processing Record 43 of Set 15 | teya
# Processing Record 44 of Set 15 | honiara
# Processing Record 45 of Set 15 | auki
# Processing Record 46 of Set 15 | gulbarga
# Processing Record 47 of Set 15 | labrea
# Processing Record 48 of Set 15 | marawi
# Processing Record 49 of Set 15 | kyzyl-suu
# Processing Record 50 of Set 15 | gat
# Processing Record 1 of Set 16 | natal
# Processing Record 2 of Set 16 | waingapu
# Processing Record 3 of Set 16 | kerema
# Processing Record 4 of Set 16 | sidi ali
# Processing Record 5 of Set 16 | moroni
# Processing Record 6 of Set 16 | bonavista
# Processing Record 7 of Set 16 | camopi
# Processing Record 8 of Set 16 | fountain
# Processing Record 9 of Set 16 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 16 | khonsa
# Processing Record 11 of Set 16 | rio gallegos
# Processing Record 12 of Set 16 | inyonga
# Processing Record 13 of Set 16 | singaraja
# Processing Record 14 of Set 16 | port blair
# Processing Record 15 of Set 16 | chapada dos guimaraes
# Processing Record 16 of Set 16 | goma
# Processing Record 17 of Set 16 | kiama
# Processing Record 18 of Set 16 | celakovice
# Processing Record 19 of Set 16 | salinopolis
# Processing Record 20 of Set 16 | palmas de monte alto
# Processing Record 21 of Set 16 | pacifica
# Processing Record 22 of Set 16 | general roca
# Processing Record 23 of Set 16 | bandundu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-9e47f25690e8> in <module>
#      61 print("-----------------------------")
#      62
# ---> 63 print(city_data.head(10))
#
# AttributeError: 'list' object has no attribute 'head'

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
print(city_data_df.columns)
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description', 'Country', 'Date'],
#       dtype='object')

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
